# %% [markdown]
# <a href="https://colab.research.google.com/github/FilSan-pt/analiseDados_curso/blob/master/trabalhoColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importar bibliotecas
import numpy as np
import pandas as pd

from google.colab import drive 

import matplotlib.pyplot as plt

# %%
#acesso à drive - montar
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#importar csv para dataset do panda
dataset = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/trabalhoAvalicaoAnaliseDados/trifactaCSV.csv', delimiter = ',')

# %%
#ver conteúdo do dataset
dataset
# Out:
#     cidade   ano  ...  endivid_perc_ult_ano  res_op_ult_ano
# 0   Lisboa  2010  ...               0.86725      2424.19744
# 1   Lisboa  2010  ...               0.55231       407.65368
# 2   Lisboa  2010  ...               0.85083      -398.13498
# 3   Lisboa  2010  ...               1.36924        56.96538
# 4   Lisboa  2010  ...               1.18062        19.93995
# ..     ...   ...  ...                   ...             ...
# 79   Porto  2018  ...               0.13792     13561.61925
# 80   Porto  2018  ...               0.64453       136.42942
# 81   Porto  2018  ...               0.51377        64.24599
# 82   Porto  2018  ...               0.20172        25.66302
# 83   Porto  2018  ...               1.15349       -27.83595
#
# [84 rows x 23 columns]

# %%
#criou-se um data para cada um dos anos para evitar a duplicação do valor das empresas para cada ano do munocípio
is_2010 = dataset[dataset['ano']==2010]

is_2018 = dataset[dataset['ano']==2018]

# %%
#ver dataset 2010 todos os dados empresas únicos, municipos duplicados x vezes o número de empresas
is_2010
# Out:
#     cidade   ano  ...  endivid_perc_ult_ano  res_op_ult_ano
# 0   Lisboa  2010  ...               0.86725      2424.19744
# 1   Lisboa  2010  ...               0.55231       407.65368
# 2   Lisboa  2010  ...               0.85083      -398.13498
# 3   Lisboa  2010  ...               1.36924        56.96538
# 4   Lisboa  2010  ...               1.18062        19.93995
# 5   Lisboa  2010  ...               0.72793        67.03034
# 6   Lisboa  2010  ...                   NaN        99.94471
# 7   Lisboa  2010  ...               0.85356         4.01036
# 8   Lisboa  2010  ...               2.91821         5.41108
# 9   Lisboa  2010  ...               1.14256        44.40579
# 10  Lisboa  2010  ...               4.51982        -8.63430
# 11  Lisboa  2010  ...               0.67913        -1.27793
# 12  Lisboa  2010  ...               7.82739       -23.60985
# 13  Lisboa  2010  ...               0.00000       -10.66400
# 14  Lisboa  2010  ...               1.74450         0.82274
# 15  Lisboa  2010  ...               1.28480       163.20892
# 16  Lisboa  2010  ...                   NaN        -6.21510
# 17  Lisboa  2010  ...               0.10840         0.00000
# 18  Lisboa  2010  ...               1.58729       -20.09711
# 19  Lisboa  2010  ...               0.00000        -0.01502
# 20  Lisboa  2010  ...               1.53112        -1.43709
# 21  Lisboa  2010  ...               0.00000         0.00000
# 22  Lisboa  2010  ...               2.13867        -0.01552
# 46  Braga   2010  ...               0.58741      2822.24216
# 47  Braga   2010  ...               0.68742       358.34208
# 48  Braga   2010  ...               0.36214       659.92621
# 49  Braga   2010  ...               0.16069      2473.53807
# 50  Braga   2010  ...               0.24974       319.58748
# 51  Braga   2010  ...               0.85364        30.47339
# 52  Braga   2010  ...               1.03457        20.42792
# 53  Braga   2010  ...               0.68848        -2.68926
# 54  Braga   2010  ...               0.29795        53.32636
# 55  Braga   2010  ...               0.01243       -16.56839
# 66  Aveiro  2010  ...               0.01689       -21.55891
# 67  Aveiro  2010  ...               0.22344         0.15237
# 70    Faro  2010  ...               3.18429       -14.15208
# 71    Faro  2010  ...               0.66037         0.51550
# 74   Porto  2010  ...               0.13792     13561.61925
# 75   Porto  2010  ...               0.64453       136.42942
# 76   Porto  2010  ...               0.51377        64.24599
# 77   Porto  2010  ...               0.20172        25.66302
# 78   Porto  2010  ...               1.15349       -27.83595
#
# [42 rows x 23 columns]

# %%
#ver dataset 2018 todos os dados empresas únicos, municipos duplicados x vezes o número de empresas
is_2018
# Out:
#     cidade   ano  ...  endivid_perc_ult_ano  res_op_ult_ano
# 23  Lisboa  2018  ...               0.86725      2424.19744
# 24  Lisboa  2018  ...               0.55231       407.65368
# 25  Lisboa  2018  ...               0.85083      -398.13498
# 26  Lisboa  2018  ...               1.36924        56.96538
# 27  Lisboa  2018  ...               1.18062        19.93995
# 28  Lisboa  2018  ...               0.72793        67.03034
# 29  Lisboa  2018  ...                   NaN        99.94471
# 30  Lisboa  2018  ...               0.85356         4.01036
# 31  Lisboa  2018  ...               2.91821         5.41108
# 32  Lisboa  2018  ...               1.14256        44.40579
# 33  Lisboa  2018  ...               4.51982        -8.63430
# 34  Lisboa  2018  ...               0.67913        -1.27793
# 35  Lisboa  2018  ...               7.82739       -23.60985
# 36  Lisboa  2018  ...               0.00000       -10.66400
# 37  Lisboa  2018  ...               1.74450         0.82274
# 38  Lisboa  2018  ...               1.28480       163.20892
# 39  Lisboa  2018  ...                   NaN        -6.21510
# 40  Lisboa  2018  ...               0.10840         0.00000
# 41  Lisboa  2018  ...               1.58729       -20.09711
# 42  Lisboa  2018  ...               0.00000        -0.01502
# 43  Lisboa  2018  ...               1.53112        -1.43709
# 44  Lisboa  2018  ...               0.00000         0.00000
# 45  Lisboa  2018  ...               2.13867        -0.01552
# 56  Braga   2018  ...               0.58741      2822.24216
# 57  Braga   2018  ...               0.68742       358.34208
# 58  Braga   2018  ...               0.36214       659.92621
# 59  Braga   2018  ...               0.16069      2473.53807
# 60  Braga   2018  ...               0.24974       319.58748
# 61  Braga   2018  ...               0.85364        30.47339
# 62  Braga   2018  ...               1.03457        20.42792
# 63  Braga   2018  ...               0.68848        -2.68926
# 64  Braga   2018  ...               0.29795        53.32636
# 65  Braga   2018  ...               0.01243       -16.56839
# 68  Aveiro  2018  ...               0.01689       -21.55891
# 69  Aveiro  2018  ...               0.22344         0.15237
# 72    Faro  2018  ...               3.18429       -14.15208
# 73    Faro  2018  ...               0.66037         0.51550
# 79   Porto  2018  ...               0.13792     13561.61925
# 80   Porto  2018  ...               0.64453       136.42942
# 81   Porto  2018  ...               0.51377        64.24599
# 82   Porto  2018  ...               0.20172        25.66302
# 83   Porto  2018  ...               1.15349       -27.83595
#
# [42 rows x 23 columns]

# %%
# 1º Qual o Distrito com maior quantidade de empresas?
# de um dos dataset anteriores contamos a quantidade de valores únicos relativamente ao distrito.
freq_cidadeEmp = is_2010.cidade.value_counts()

print(freq_cidadeEmp)
#idxmax devolve a posição do valor máximo numa coluna específica ou linha. como só temos uma coluna devolve a posição do valor máximo
index_MaxEmp = freq_cidadeEmp.idxmax()

print("O distrito com maior numero de empresas é", index_MaxEmp, "com o valor de ", freq_cidadeEmp.max(), " empresas.")
# Out:
# Lisboa    23
# Braga     10
# Porto      5
# Aveiro     2
# Faro       2
# Name: cidade, dtype: int64
# O distrito com maior numero de empresas é Lisboa com o valor de  23  empresas.

# %%
# 2º Qual o Distrito onde existe um volume de negócios mais elevado?´
# Como se fala de volume de negócio irão ser usados os valores dos proveitos operacionais

freq_cidadeProv = is_2010.groupby('cidade')['prov_oper_ult_ano'].sum()

print(freq_cidadeProv)

index_MaxProv = freq_cidadeProv.idxmax()

print("O distrito com maior volume de negócios é", index_MaxProv, "com o valor de ", freq_cidadeProv.max(), ".")
# Out:
# cidade
# Aveiro      438.347590
# Braga     35407.578149
# Faro        102.339500
# Lisboa    41547.437259
# Porto     16824.315390
# Name: prov_oper_ult_ano, dtype: float64
# O distrito com maior volume de negócios é Lisboa com o valor de  41547.43725899999 .

# %%
# 3º Qual a sustentabilidade económica de cada distrito? (rendimento – despesas)
#criar e data set do ano 2010 e 2018 só com as colunas referentes a receitas e despesas sem os valores duplicados
nodupl_2010 = is_2010.iloc[:, [0,2,5,6]].drop_duplicates()

nodupl_2018 = is_2018.iloc[:, [0,2,5,6]].drop_duplicates()

# %%
#correr só uma vez, depois de adicionada a coluna dá erro por já existir

nodupl_2010.insert(1,"Sustentabilidade", nodupl_2010.receitas_camara - nodupl_2010.despesas_camara)

# %%
#correr só uma vez, depois de adicionada a coluna dá erro por já existir

nodupl_2010.insert(2,"Sust_per_capita", nodupl_2010.Sustentabilidade / nodupl_2010.pop_total)

# %%
#ver para responder à pergunta

nodupl_2010
# Out:
#     cidade  Sustentabilidade  ...  despesas_camara  receitas_camara
# 0   Lisboa          36365200  ...        564333000        600698200
# 46  Braga            4659400  ...         81048300         85707700
# 66  Aveiro           1705300  ...         44342400         46047700
# 70    Faro           3453100  ...         27536600         30989700
# 74   Porto           2055000  ...        183176900        185231900
#
# [5 rows x 6 columns]

# %%
#correr só uma vez, depois de adicionada a coluna dá erro por já existir

nodupl_2018.insert(1,"Sustentabilidade", nodupl_2018.receitas_camara - nodupl_2018.despesas_camara)

# %%
#correr só uma vez, depois de adicionada a coluna dá erro por já existir

nodupl_2018.insert(2,"Sust_per_capita", nodupl_2018.Sustentabilidade / nodupl_2018.pop_total)

# %%
#ver para responder à pergunta

nodupl_2018
# Out:
#     cidade  Sustentabilidade  ...  despesas_camara  receitas_camara
# 23  Lisboa         -32664100  ...        820249300        787585200
# 56  Braga            6029000  ...         88142800         94171800
# 68  Aveiro           -637400  ...         66101500         65464100
# 72    Faro           8596500  ...         32666700         41263200
# 79   Porto          16022800  ...        202746500        218769300
#
# [5 rows x 6 columns]

# %%
# 4º Qual o distrito com maior densidade populacional?
# criar data set do ano 2010 e 2018 só com a coluna referente a densidade populacional sem os valores duplicados

dens_nodupl_2010 = is_2010.iloc[:, [0,2,3]].drop_duplicates()

dens_nodupl_2018 = is_2018.iloc[:, [0,2,3]].drop_duplicates()

dens_nodupl_2010.insert(1,"dens_pop", dens_nodupl_2010.pop_total / dens_nodupl_2010.km2)

dens_nodupl_2018.insert(1,"dens_pop", dens_nodupl_2018.pop_total / dens_nodupl_2018.km2)

# %%
# ver para responder
dens_nodupl_2010
# Out:
#     cidade     dens_pop  pop_total    km2
# 0   Lisboa  6468.904594     549210   84.9
# 46  Braga    986.630316     180948  183.4
# 66  Aveiro   396.123482      78274  197.6
# 70    Faro   318.711596      64316  201.8
# 74   Porto  5788.647343     239650   41.4

# %%
# ver para responder
dens_nodupl_2018
# Out:
#     cidade     dens_pop  pop_total    km2
# 23  Lisboa  5061.478521     506654  100.1
# 56  Braga    990.463468     181651  183.4
# 68  Aveiro   393.588057      77773  197.6
# 72    Faro   300.824284      60947  202.6
# 79   Porto  5191.690821     214936   41.4

# %%
# 5º Alguma(s) da(s) empresas apresenta(m) prejuízo?
# empresas estão duplicadas em 2 dataset, is_2010 e em is_2018, como tal basta escolher um deles para responder
is_less0 = is_2010[is_2010['res_op_ult_ano'] < 0]

prej_emp = is_less0.iloc[:, [14,22]].sort_values(ascending = True, by = 'res_op_ult_ano')

# %%
#ver para responder
prej_emp
# Out:
#                                                  nome  res_op_ult_ano
# 2                          INGREDIENTE PRIMAVERA, LDA      -398.13498
# 78                   PRIMAVERANIMADA, UNIPESSOAL, LDA       -27.83595
# 12                   AVIARIO - AQUARIO PRIMAVERA, LDA       -23.60985
# 66                             PRIMAVERA À VISTA, LDA       -21.55891
# 18                PRAÇA DA PRIMAVERA, UNIPESSOAL, LDA       -20.09711
# 55  PRIMAVERA VERDE - INVESTIMENTOS IMOBILIÁRIOS, LDA       -16.56839
# 70             MANOBRAS DA PRIMAVERA, UNIPESSOAL, LDA       -14.15208
# 13    MINIMERCADO PRIMAVERA DA AJUDA, UNIPESSOAL, LDA       -10.66400
# 10                          ESTRELA DA PRIMAVERA, LDA        -8.63430
# 16                           TABACARIA PRIMAVERA, LDA        -6.21510
# 53              RETIRO DA PRIMAVERA, RESTAURANTE, LDA        -2.68926
# 20  CHEIROS DE PRIMAVERA - IMPORTAÇÃO & EXPORTAÇÃO...        -1.43709
# 11              PRIMAVERA DISPONÍVEL, UNIPESSOAL, LDA        -1.27793
# 22  TEMÁTICA DA PRIMAVERA - ATIVIDADES HOTELEIRAS,...        -0.01552
# 19  TESOUROS DE PRIMAVERA INVESTIMENTOS IMOBILIÁRI...        -0.01502

# %%
# 6º Qual a empresa mais lucrativa?

dataset.iloc[[is_2010['res_op_ult_ano'].idxmax()],[14,-1]]
# Out:
#                                   nome  res_op_ult_ano
# 74  EFANOR - INVESTIMENTOS, SGPS, S.A.     13561.61925

# %%
# 7º Qual a média do Resultado Operacional das empresas, por ano e por distrito? A Distribuição é normal? Porquê?

mean_emp = is_2010.groupby(['cidade','ultimo_ano_disp'])['res_op_ult_ano'].mean()

# %%
# ver a média agrupada do resultado
mean_emp
# Out:
# cidade  ultimo_ano_disp
# Aveiro  12/31/2018          -10.703270
# Braga   12/31/2007           30.473390
#         12/31/2014          659.926210
#         12/31/2018          753.525802
# Faro    12/31/2012            0.515500
#         12/31/2016          -14.152080
# Lisboa  12/31/2006          -23.609850
#         12/31/2008           46.864805
#         12/31/2010         2424.197440
#         12/31/2011           -1.437090
#         12/31/2013            4.010360
#         12/31/2014          407.653680
#         12/31/2015            9.969975
#         12/31/2016           -5.147813
#         12/31/2018           -8.040336
# Porto   12/31/2015          136.429420
#         12/31/2018         3405.923077
# Name: res_op_ult_ano, dtype: float64

# %%
# gráfico dos resultados operacionais para verificar se é uma distribuição normal
x = is_2010.iloc[:,-1]
is_2010[is_2010['res_op_ult_ano'] < 0]

plt.hist(x)
plt.title('Histograma das frequências')
plt.xlabel('Resultado operacional')
plt.ylabel('Frequências')
# Out:
# Text(0, 0.5, 'Frequências')

# %%
# describe para medidas estatísticas base
x.describe()
# Out:
# count       42.000000
# mean       553.980336
# std       2164.323572
# min       -398.134980
# 25%         -2.376217
# 50%          4.710720
# 75%         91.716117
# max      13561.619250
# Name: res_op_ult_ano, dtype: float64

# %%
# 68,26% dos valores têm de se localizar entre [média - desvio padrão; média + desvio padrão]
n_v = x[(x > -1610) & (x < 2729)].count()
e_normal = n_v/x.count() > 0.6826

e_normal
# Out:
# True

# %%
# 8º Qual o distrito com melhor desempenho nas redes sociais, porquê?

rede_sociais = is_2010.iloc[:, [0, 9,10,11,12]].drop_duplicates()
rede_sociais
# Out:
#     cidade  facebook_seguidores  ...  instagram_ashtag  twitter_followers
# 0   Lisboa               404965  ...          10541541            91100.0
# 46  Braga                104939  ...            848859            63800.0
# 66  Aveiro                42423  ...            663067              832.0
# 70    Faro                28573  ...           1377499                NaN
# 74   Porto               128147  ...           8055322              140.0
#
# [5 rows x 5 columns]

# %%
sum_redes =np.array(rede_sociais.sum(axis=0))

rede_sociais.insert(2,"racio_face", rede_sociais.facebook_seguidores / sum_redes[1])

# %%
rede_sociais.insert(4,"racio_yout", rede_sociais.youtube_seguidores / sum_redes[2])

# %%
rede_sociais.insert(6,"racio_inst", rede_sociais.instagram_ashtag / sum_redes[3])

# %%
rede_sociais.insert(8,"racio_twit", rede_sociais.twitter_followers / sum_redes[4])

# %%
rede_sociais
# Out:
#     cidade  facebook_seguidores  ...  twitter_followers  racio_twit
# 0   Lisboa               404965  ...            91100.0    0.584454
# 46  Braga                104939  ...            63800.0    0.409310
# 66  Aveiro                42423  ...              832.0    0.005338
# 70    Faro                28573  ...                NaN         NaN
# 74   Porto               128147  ...              140.0    0.000898
#
# [5 rows x 9 columns]

# %%
# 9º Qual a o resultado operacional por funcionário / ano? (Resultado Operacional / Nº funcionários)
# como os dados da empresa só são referentes a um só ano irá-se calcular o Resultado Operacional / Nº funcionários

func_empr = is_2010.iloc[:, [14,19,22]]

# %%
func_empr.insert(3,"res/func", func_empr.res_op_ult_ano / func_empr.num_emp_ult_ano )

# %%
# ver resposta
func_empr.sort_values(ascending = False, by = 'res/func')
# Out:
#                                                  nome  ...     res/func
# 15  JARDIM PRIMAVERA - EMPREENDIMENTOS IMOBILIÁRIO...  ...          inf
# 9                     PALCO DA PRIMAVERA EVENTOS, LDA  ...          inf
# 74                 EFANOR - INVESTIMENTOS, SGPS, S.A.  ...          inf
# 75   QUINTA DA PRIMAVERA - PROMOÇÃO IMOBILIÁRIA, S.A.  ...          inf
# 54  PRIPT - BUSINESS SOFTWARE SOLUTIONS, UNIPESSOA...  ...          inf
# 49                             PRIMAVERA - SGPS, S.A.  ...  1236.769035
# 50                            ACTOS DE PRIMAVERA, LDA  ...   106.529160
# 6                           PASTELARIA PRIMAVERA, LDA  ...    99.944710
# 52                           PINKCAR, UNIPESSOAL, LDA  ...    20.427920
# 46      PRIMAVERA - BUSINESS SOFTWARE SOLUTIONS, S.A.  ...    12.543298
# 0    SIERRA CORPORATE SERVICES - APOIO A GESTÃO, S.A.  ...    10.404281
# 51    REAL PRIMAVERA - IMOBILIÁRIA E CONSTRUÇÕES, LDA  ...    10.157797
# 48  TECHNOLOGY - PRIMAVERA SOFTWARE FACTORY, UNIPE...  ...     8.683240
# 77                             DSTYPE, UNIPESSOAL LDA  ...     8.554340
# 1                           MAILTEC CONSULTORIA, S.A.  ...     8.153074
# 76                           RITMOS DA PRIMAVERA, LDA  ...     7.138443
# 8                 PRIMAVERA NO PRATO, UNIPESSOAL, LDA  ...     5.411080
# 5                                 MIL PRIMAVERAS, LDA  ...     3.942961
# 47                    F3M - INFORMATION SYSTEMS, S.A.  ...     3.479049
# 4                 PRIMAVERA DE CORES, UNIPESSOAL, LDA  ...     1.329330
# 14  PRIMAVERA MÁGICA - IMAGEM E COMUNICAÇÃO, UNIPE...  ...     0.822740
# 3                ALÇADO DE PRIMAVERA, UNIPESSOAL, LDA  ...     0.678159
# 7                  PRIMAVERA MÁGICA - UNIPESSOAL, LDA  ...     0.668393
# 71                                 ESTÚDIO DSTHK, LDA  ...     0.257750
# 67                              DSTM CONSULTORES, LDA  ...     0.030474
# 17             PÉROLA DA PRIMAVERA - IMOBILIÁRIA, LDA  ...     0.000000
# 53              RETIRO DA PRIMAVERA, RESTAURANTE, LDA  ...    -0.537852
# 11              PRIMAVERA DISPONÍVEL, UNIPESSOAL, LDA  ...    -0.638965
# 70             MANOBRAS DA PRIMAVERA, UNIPESSOAL, LDA  ...    -3.538020
# 10                          ESTRELA DA PRIMAVERA, LDA  ...    -4.317150
# 16                           TABACARIA PRIMAVERA, LDA  ...    -6.215100
# 78                   PRIMAVERANIMADA, UNIPESSOAL, LDA  ...    -9.278650
# 13    MINIMERCADO PRIMAVERA DA AJUDA, UNIPESSOAL, LDA  ...   -10.664000
# 12                   AVIARIO - AQUARIO PRIMAVERA, LDA  ...   -11.804925
# 66                             PRIMAVERA À VISTA, LDA  ...         -inf
# 55  PRIMAVERA VERDE - INVESTIMENTOS IMOBILIÁRIOS, LDA  ...         -inf
# 22  TEMÁTICA DA PRIMAVERA - ATIVIDADES HOTELEIRAS,...  ...         -inf
# 19  TESOUROS DE PRIMAVERA INVESTIMENTOS IMOBILIÁRI...  ...         -inf
# 18                PRAÇA DA PRIMAVERA, UNIPESSOAL, LDA  ...         -inf
# 2                          INGREDIENTE PRIMAVERA, LDA  ...         -inf
# 20  CHEIROS DE PRIMAVERA - IMPORTAÇÃO & EXPORTAÇÃO...  ...         -inf
# 21                          DSTF - INVESTIMENTOS, LDA  ...          NaN
#
# [42 rows x 4 columns]

# %%
# 10º Elabore um gráfico que demonstre o desempenho dos distritos nas redes sociais, juntamente com a sua população total e o número de desempregados.
# array com nome das cidades
nome_cidade = np.array(is_2018['cidade'].drop_duplicates())

#somatório das redes sociais por cidade
arr_redSoci_Cid = np.array(rede_sociais.sum(axis=1))

#array com a população total
arr_pop_tot = np.array(is_2018['pop_total'].drop_duplicates())

#array desempregados
arr_desemp = np.array(is_2018['desempregados'].drop_duplicates())

# %%
# gráfico das redes sociais
plt.plot(nome_cidade,arr_redSoci_Cid)

# %%
# gráfico da população total 

plt.plot(nome_cidade,arr_pop_tot)

# %%
# gráfico desempregados
plt.plot(nome_cidade,arr_desemp)

# %%
plt.plot(nome_cidade,arr_redSoci_Cid)
plt.plot(nome_cidade,arr_pop_tot)
plt.plot(nome_cidade,arr_desemp)

plt.legend(['Redes Sociais por cidade', 'População Total', 'Desempregados'], loc='upper left')


plt.show()
